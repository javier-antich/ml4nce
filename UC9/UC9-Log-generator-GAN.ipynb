# %% [markdown]
# # Connection to drive and path definition

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import sys
sys.path.append('/content/drive/MyDrive/Colab Notebooks/final/SANDS')
path_files ='/content/drive/MyDrive/Colab Notebooks/final/UC9'

# %% [markdown]
# # Import libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import mean_absolute_error,mean_absolute_percentage_error
import time
from calendar import timegm, monthrange
from datetime import datetime, timedelta
import math
import sands
from sklearn.preprocessing import MinMaxScaler, StandardScaler
import tensorflow as tf
from tensorflow import keras
from os import listdir
from os.path import isfile, join
from tensorflow.keras import layers
from tensorflow.keras.layers import Embedding, LSTM, Dense, Bidirectional
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.models import Sequential
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import ModelCheckpoint
from tensorflow.keras.metrics import CategoricalAccuracy,Accuracy,BinaryAccuracy


import statsmodels.api as sm
from statsmodels.tsa.stattools import adfuller, kpss
from statsmodels.tsa.api import ExponentialSmoothing
from scipy.stats import iqr


import json

import nltk
from nltk.tokenize import RegexpTokenizer
from sklearn.feature_extraction.text import CountVectorizer,TfidfVectorizer
from nltk.tokenize import sent_tokenize, word_tokenize
from nltk.corpus import stopwords
import string
import re
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split
from sklearn.model_selection import cross_val_score
from sklearn.metrics import classification_report, confusion_matrix
from sklearn import metrics
from sklearn.linear_model import LogisticRegression
from sklearn.naive_bayes import MultinomialNB
from sklearn.svm import LinearSVC
from sklearn.manifold import TSNE
from progressbar import ProgressBar
import h5py

# %% [markdown]
# # Functions for data processing

# %%
max_len = 210
latent_len = 512
training_size = 20000
testing_size = 2000
total_subset = training_size+testing_size
log_len = 210
batch_size = 256
nb_epoch = 200
training_steps_per_epoch = np.ceil(training_size/batch_size)
validation_steps_per_epoch = np.ceil(testing_size/batch_size)
training_file = 'log_messages.txt'
training_data_file = 'training_data_binary.h5'
noise_len = 128

# %%
with open(join(path_files,'c_n_dict_pred.txt'), 'r') as infile:
    c_n_dict=json.load(infile)

with open(join(path_files,'n_c_dict_pred.txt'), 'r') as infile:
    n_c_dict=json.load(infile)
n_c_dict = { int(key):value for key,value in n_c_dict.items()}

# %%
def remove_too_long(log_list):
    training_logs = []
    for log in log_list:
      if len(log)<max_len:
        training_logs.append(log)
    return training_logs

# %%
def tokenize_logs(log_list):
    training_logs_c = []
    for log in log_list:
      training_logs_c.append([char for char in log])
    return training_logs_c

# %%
def one_hot_encode(log_list_c):
    training_array=np.zeros((len(log_list_c),max_len))
    training_array_b=np.zeros((len(log_list_c),max_len,len(c_n_dict)))
    for i in range(len(log_list_c)):
      log = log_list_c[i][:-1]
      log_n = [c_n_dict[c] for c in log]
      log_n += [c_n_dict[' ']]*(max_len-len(log_n))
      training_array[i,:]=log_n
      for j in range(training_array_b.shape[1]):
        training_array_b[i,j,int(training_array[i,j])]=1
    return training_array_b

# %%
def load_data(Train_file, idx, batch_size):
  log_batch = [next(Train_file) for x in range(batch_size)]
  return log_batch

# %%
def batch_generator(Train_file, batch_size, steps):
  idx=1
  with h5py.File(Train_file,'r') as hf:
      while True:
        start_index = (idx-1)*batch_size
        stop_index = start_index + batch_size
        X_batch = hf['X_train_latent'][start_index:stop_index,:]
        yield (X_batch,X_batch)
        if idx < steps:
          idx +=1
        else:
          idx=1

# %%
def load_batch(Train_file, batch_size, start):
  with h5py.File(Train_file,'r') as hf:
        start_index = start
        stop_index = start_index + batch_size
        X_batch = hf['X_train_latent'][start_index:stop_index,:latent_len]
        return X_batch,X_batch

# %%
def data_loader(Train_file, batch_size, steps):
  idx=1
  go_on = True
  x = np.zeros((batch_size*int(steps),max_len,len(c_n_dict)))
  with open(Train_file,'r', encoding = "ISO-8859-1") as myfile:
      while go_on:
        log_batch = load_data(myfile, idx-1,batch_size)
        log_batch = remove_too_long(log_batch)
        log_batch_b = one_hot_encode(tokenize_logs(log_batch))
        x[(idx-1)*batch_size:idx*batch_size,:,:] = log_batch_b
        if idx < steps:
          idx +=1
        else:
          go_on = False
  return x

# %%
def binarize_log(generated_log):
  binarized_log = np.zeros(generated_log.shape)
  
  for i in range(generated_log.shape[0]):
    
    for j in range(generated_log.shape[1]):
      max_value = np.max(generated_log[i,j])
      binarized_log[i,j,:]=np.where(generated_log[i,j,:]==max_value,1,0)
   
  return binarized_log

# %%
def print_log(binarized_log):
  max_value_index = np.argmax(binarized_log,axis=-1)
  new_logs = []
  for i in range(binarized_log.shape[0]):
    char_list = [n_c_dict[j] for j in max_value_index[i]]
    new_log =''.join(char_list)
    print('Generated log: ',new_log)
    new_logs.append(new_log)
  return new_logs

# %% [markdown]
# # Models definition

# %%
def make_decoder_model():
  decoder_model = tf.keras.Sequential()
  decoder_model.add(layers.RepeatVector(log_len,input_shape=(512,)))
  decoder_model.add(Bidirectional(LSTM(256,return_sequences=True)))
  decoder_model.add(layers.TimeDistributed(Dense(len(c_n_dict),activation='softmax')))
  decoder_model.load_weights(join(path_files,'weights_decoder_best.hdf5'))
  return decoder_model

# %%
def make_generator_model():
    gen_model = tf.keras.Sequential()
    gen_model.add(Dense(1024,activation='relu',input_shape=(noise_len,)))
    gen_model.add(Dense(512,activation='relu'))
    gen_model.add(Dense(latent_len,activation='tanh'))
    return gen_model

# %%
decoder_model = make_decoder_model()

# %%
decoder_model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  repeat_vector_1 (RepeatVect  (None, 210, 512)         0
#  or)
#
#  bidirectional_1 (Bidirectio  (None, 210, 512)         1574912
#  nal)
#
#  time_distributed_1 (TimeDis  (None, 210, 68)          34884
#  tributed)
#
# =================================================================
# Total params: 1,609,796
# Trainable params: 1,609,796
# Non-trainable params: 0
# _________________________________________________________________

# %%
generator_model = make_generator_model()

# %%
generator_model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_2 (Dense)             (None, 1024)              132096
#
#  dense_3 (Dense)             (None, 512)               524800
#
#  dense_4 (Dense)             (None, 512)               262656
#
# =================================================================
# Total params: 919,552
# Trainable params: 919,552
# Non-trainable params: 0
# _________________________________________________________________

# %%
noise = tf.random.normal([5,noise_len, 1])
generated_log = generator_model(noise, training=False)
generated_log_np = tf.multiply(generated_log,1)

# %%
generated_log_np
# Out:
# <tf.Tensor: shape=(5, 512), dtype=float32, numpy=
# array([[ 0.4686261 ,  0.11976805, -0.64332235, ...,  0.00119619,
#          0.14156789, -0.00922195],
#        [ 0.30733234,  0.4541695 , -0.3975639 , ..., -0.11179242,
#          0.15578625,  0.1067327 ],
#        [ 0.22862591,  0.12244097, -0.42136833, ...,  0.34721142,
#          0.1372217 ,  0.16629401],
#        [ 0.42050344, -0.00882316, -0.27556613, ...,  0.0197808 ,
#          0.26825127,  0.392187  ],
#        [ 0.03635823,  0.2617016 , -0.32123345, ...,  0.22509287,
#         -0.11603758,  0.4230603 ]], dtype=float32)>

# %%
def make_discriminator_model():

  mymodel = tf.keras.Sequential()
  mymodel.add(Dense(1024,activation='relu',input_shape=(latent_len,)))
  mymodel.add(Dense(512,activation='relu'))
  mymodel.add(Dense(512,activation='relu'))
  mymodel.add(Dense(512,activation='relu'))
  mymodel.add(Dense(1))

  return mymodel

# %%
discriminator_model = make_discriminator_model()

# %%
discriminator_model.summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_5 (Dense)             (None, 1024)              525312
#
#  dense_6 (Dense)             (None, 512)               524800
#
#  dense_7 (Dense)             (None, 512)               262656
#
#  dense_8 (Dense)             (None, 512)               262656
#
#  dense_9 (Dense)             (None, 1)                 513
#
# =================================================================
# Total params: 1,575,937
# Trainable params: 1,575,937
# Non-trainable params: 0
# _________________________________________________________________

# %%
cross_entropy = tf.keras.losses.BinaryCrossentropy(from_logits=True)

# %%
def discriminator_loss(real_output, fake_output):
    real_loss = cross_entropy(tf.ones_like(real_output), real_output)
    fake_loss = cross_entropy(tf.zeros_like(fake_output), fake_output)
    total_loss = real_loss + fake_loss
    return total_loss

# %%
def generator_loss(fake_output):
    fake_loss = cross_entropy(tf.ones_like(fake_output), fake_output)
    return fake_loss

# %%
generator_optimizer = tf.keras.optimizers.Adam(1e-4)
discriminator_optimizer = tf.keras.optimizers.Adam(1e-4)

# %%
checkpoint_dir = path_files
checkpoint_prefix = join(checkpoint_dir, "ckpt")
checkpoint = tf.train.Checkpoint(generator_optimizer=generator_optimizer,
                                 discriminator_optimizer=discriminator_optimizer,
                                 generator=generator_model,
                                 discriminator=discriminator_model)

# %%
noise_dim = 1
num_examples_to_generate = 16

seed = tf.random.normal([num_examples_to_generate,noise_len, noise_dim])

# %% [markdown]
# # Training functions

# %%
def train_step(real_logs):
    noise = tf.random.normal([batch_size, noise_len, noise_dim])
    #print('next_train_step')
    with tf.GradientTape() as gen_tape, tf.GradientTape() as disc_tape:
      generated_logs = generator_model(noise, training=True)
      real_output = discriminator_model(real_logs, training=True)
      fake_output = discriminator_model(generated_logs, training=True)
      gen_loss = generator_loss(fake_output)
      disc_loss = discriminator_loss(real_output, fake_output)
    #print('   generator loss: ',gen_loss,'  discriminator loss:',disc_loss)
    gradients_of_generator = gen_tape.gradient(gen_loss, generator_model.trainable_variables)
    gradients_of_discriminator = disc_tape.gradient(disc_loss, discriminator_model.trainable_variables)
    generator_optimizer.apply_gradients(zip(gradients_of_generator, generator_model.trainable_variables))
    discriminator_optimizer.apply_gradients(zip(gradients_of_discriminator, discriminator_model.trainable_variables))
    return 0

# %%
def generate_and_save_logs(model, epoch, test_input):
  predictions = model(test_input, training=False)
  generated_log_np = tf.multiply(predictions,1)
  new_logs = print_log(binarize_log(decoder_model.predict(predictions)))
  file1 = open(join(path_files,'logs_at_epoc_{:04d}.log'.format(epoch)), 'w', encoding = "ISO-8859-1")
  file1.writelines(new_logs)

# %%
def train(training_size, epochs, batch):
  for epoch in range(epochs):
    start = time.time()
    batch_start = 0
    batch_number=1
    while (batch_start+batch)<training_size:
      (training_set,_) = load_batch(join(path_files,training_data_file),batch,batch_start)
      train_step(training_set)
      batch_start += batch
      batch_number +=1
    # Produce logs as you go
    print('Epoch:',epoch)
    generate_and_save_logs(generator_model,
                             epoch + 1,
                             seed)

    # Save the model every 15 epochs
    if (epoch + 1) % 15 == 0:
      checkpoint.save(file_prefix = checkpoint_prefix)

    print ('Time for epoch {} is {} sec'.format(epoch + 1, time.time()-start))

  # Generate after the final epoch
  generate_and_save_logs(generator_model,
                           epochs,
                           seed)

# %% [markdown]
# # GAN Training

# %%
train(training_size, nb_epoch, batch_size)
# Out:
# Epoch: 0
# 1/1 [==============================] - 3s 3s/step
# Generated log:  20222-10-01 001:10::01   E__mgr1111]::  %PRRRSNNN____RRRFF_______IAAREEEEVEN    ::    eeeeff                                              020000022222222000000----11100 00011110:::::0111       __mgr1171]]:: %%E
# Generated log:  20222-10-01  01:20::01    f_mNr[111]]:: %EERRENNNNNN__GGF______IIIARREEEEEN    :::   eeeefff                                              00000022222222200000000000000000-0000  0011111:::::01111      ___mN[888]
# Generated log:  20222-10-001 01::1:::11   f__mgr1111]::  %EEEEENNNNT___GRHF______IIIAAREEEEVENN    :     eeeffff                                              22222222222000000000000000000000000--0001  00111222:::::00111   bf__
# Generated log:  20222-10-01  01:20::01    f_mmr[111]]:: %ERRRRSSAT___GGFFF______IAAAEEEEEVVNN   ::      eeeeff                                                   02222222200000000000000--0111110011111::::00111       ___mr[388]]
# Generated log:  20222-10-01 011:15::011  f__mgr1111]::  %PRRRRSSAT___RRR3FS______HAAGEEEEEVEN    :      eeeff                                            0000002222222000000-----1111001001111100::::01111      ___mr[111]]::  %PR
# Generated log:  20222-10-001 01::1:::11   f__mgr1111]::  %ERRRSNNAT___GGR3FT______IAAAEEEEEVENN   :      eeefff                                              22222222222000000000000000000-----00011 0011222::::::0111      s___mg
# Generated log:  20222-10-01 001:15::01   E__mmr1111]]:  %EEFEENNNT__RGGFFTT_____IAAAEEEEEVVENN   ::     eeeeff                         0            :::::::    222222000000000000-----111100100011120::::01111       s___mr[388]]:
# Generated log:  20222-10-01  01:10::01    f__mr[1111]:: %%GRRRSSSAT__RRRR3SST____IIAAAEEEEVVENN  :::    eeeefff                       1000                       0000022221000000000000--00011 0011:11::::01111      f__mmr1788]]:
# Generated log:  20222-10-01  01:10::01    f_mmr[111]]:: %EERRESNNN___GGIHTT_____IIAAREEEEVVNN   :::   eeeeffff                        0000            ::::::    222222200000000000000000---0001  0011220::::01111      __Nmmr8888]
# Generated log:  20222-10-01 011:15::01   f__mg[1111]:: %%ERRRSSSTT_GGGGFFST______HAAEEEEVVVN   ::     eeeffff                                               0000002222000000000000---0000  0001:20:::::0011      E__mgr1111]]:  %%
# Generated log:  20222-10-01 001:15::01   l__mgr1111]]:: %%ERRRSSAT___RGRFFT______IAAREEEEVVENN  :::    eeeefff                                   :           222200222222000000000------11000100001122::::001111       ___mmr8888]
# Generated log:  20222-10-01  01:20::011   f_mNr1111]::  %SRRRRNNNATF__GI3F_______IAAAEEEEEVVN    ::    eeeeff                                            02202222222210000-----111111110111110::::00111     s___N_1111]:::  %GRRR-
# Generated log:  20222-10--01 01::1:::01    __mNr1111]]:  %EERRENNNT__FRGGFF______IIAAREEEEVVN    ::     eeeffff                                                00000222222000000000000000000000000--0000  00002:::::::0111     s__
# Generated log:  20222-10-011 01:25::011   f_mmr[111]]:: %%RRRRSSAT___GGRFF______IIAAREEEEVEEN  :::    eeeeffff                                               2220002222200000000000000000--001  0011222::::00111     f___mr[388]]:
# Generated log:  202222110-01 001:20::011   f__mgr1111]::  %EEEEENNNN___RRRFFF_____IIAAAEEEEEVVNN   :::    eeeffff                                                22222222220000000000000000000000000--00001 00111222:::::011111
# Generated log:  202222110-01  01:20:::01   E__mNr1111]::  %EEEEENNNNNN__RRRFF_____IIAAREEEEVENN   :::    eeeeffff                         000            0000 2222222221000000000000000000000001 00011112:::::001111      s__NmrN8
# Time for epoch 1 is 11.259551525115967 sec
# Epoch: 1
# 1/1 [==============================] - 0s 22ms/step
# Generated log:  2022-10-01 00:00:00:: %EVVMO[2993]:: %GGTTNNNIII---:IIOI ::::   rrn                     d          xxx      00000                                                                                                0
# Generated log:  2022-10-001 00:00:001: %ENVMMO[2993]:: GGNT-NNNFIII-::::    1     rrg:                                  xx        00000
# Generated log:  2022-10-01 00:00:00:: %ENVMOO-2200:: %MGT-NNNFII---:_OOOII2::    rrgg                    ddd    PPP  xx         00000
# Generated log:  2022-10-01 01:00:00:: %EVVmg[17000]::%GGTRRRNNFRRR33HHHHHMII::WWWWnnnn                           1    ..0IIII000000                                                                                              0
# Generated log:  2022-10-01 00:00:00:: %EVVMg[99999]: %GGTTRNNFFR--HHHHOII::::  WWnnn      ss            ddd    PP   xxx  II00000000                                                                          00000000000000000000:
# Generated log:  2022-10-001 01:00:001: %ENVMMO[2270::: GGBTRNNFIIIID::::OIII      rrf                                  xxx       00000
# Generated log:  2022-10-01 00:00:00:: %EVVMgN-2230:: %MGTTNNNIIII-::::  I11    Wrrg::                               xxxx
# Generated log:  2022--0--01 00:00:001: %ENVMMO[2233]::%GGNT-NNFIII---:::OII11     frgg                             111xxxx  IIIII00000                                                                                         000
# Generated log:  2022-10-01100:00:00:: %ENVMOO-2273:: GGGT-NNOFIRI--:::OOII     rrrg    ss   n                      xxxxx      00000
# Generated log:  2022-10-01 01:00:00:: %EVVMO[2793]:: %GBT-NNNFIII-:::OOO I      rrggg:                          P   xxxxxIIIIIII0000
# Generated log:  2022-10-01 00:00:00:: %EVVmgO22200]: %%GNT-NNNFII---:HIOIII ::   rnngg                                 xIIIIIIII0000000                                                                                 0000000000
# Generated log:  2022-10-01100:00::01: %ENVmg[1777]]: %GGTTNNNFFII3-HHHOOOII   WWWnngg                           PP1   xxx III0000000000                                                         0000000000000000000-0011 00:::::::
# Generated log:  2022-10--01 00:00:001: %ENVmgO[2933:::%GMNT-NNFIII---::   I6     rrrr::                     ee     1100 xxx IIIII00000
# Generated log:  2022-10-01100:00::01:  ENVMMO[9999]:: GGGTRNNFFII--H:HOOIIII:    nnng                    ddd    PPP    xx III0000000000UU                                                                             000000000000
# Generated log:  20222100-01 01:10::01:  %NVVMO[2223::: %GBT-NNNIIIII:::              ::                                  xx                                                                                               00000000
# Generated log:  2022-10--01 00:00::01:  ENVMgO[2203]:: %GBT-NNNIIII--:::OOII1     frrr     ss                           xxxx      0000
# Time for epoch 2 is 2.6269662380218506 sec
# Epoch: 2
# 1/1 [==============================] - 0s 20ms/step
# Generated log:  2022-10-01 01:55:01:  Ef_mgr[999]]: %BNTTTNEEEEMMR3--TTHHHHHANGEEEVENT ::    eeesffiinnn     ..........0000aaaaa  aaattttttttoooooonnnnnnn
# Generated log:  2022-10-01 01:20:01:  gx_mgr[999]]: %NNTTTNEEEEMMR3---T__HHHAAGEEEEEN  ::    eeeeffiinnn      ...........00eaaaaaaaaaaaatttttttoooooonnnnn
# Generated log:  2022-10-01 01:50:01:  gf_mgr[999]]: %MNTTTNEEEEMMR33--T__HHHAAGGEEVENN ::     eeefffiinnn     ...........00eaaae  aaaatttttttttooooooonnnn
# Generated log:  2022-10-01 01:00:01: bgf_mgr[9999]: %NNTT-STEEEMMRR---STAT_HHANGGEEVENN ::     eeefffiinnn    ............0cccaaaaaaaaattttttttooooiiiiiveee
# Generated log:  2022-10-01 01:05:01:  gf_mgr[999]]: %NNTTTTTEEEMMGR---TTTT_HHAGGEEEVEN  ::    eerssfiil         .......0000eeeaaaaaaa   ttttuuuunnnnvvvvv
# Generated log:  2022-10-01 01:20:01: bgp_mgr[999]]: %BNT-TTEEEEMMRR3--TTTT_HHANGEEEVENN ::     eeessiiinn     11.........0ccccaaaaaaaaaatttttttooooiiiiivveecc
# Generated log:  2022-10-01 01:00:01:  gf_mgr[999]]: %BNTTTNEEEEMMR----TT__HHAAGGEEVENN ::    eeeeffiiinn      .........00caaaaaaaaa  ttttttttoooinnnvvvvve
# Generated log:  2022-10-01 01:20:01:  gf_mgr[999]]: %MNTTTNEEEEMMR----T__HHHANGEEEVENT ::    eeeefffiinno   ............000ccaaaaaaaaaaaaattttuooooooiiieee
# Generated log:  2022-10-01 01:50:01:  gN_mgr[999]]: %BBT-TTEEEEMMR3---THHHHHAGGEEEVENN ::    eeeesfiiinno    ...........00ccaaaaaaaaaatttttttttoooooooo
# Generated log:  2022-10-01 01:00:01:  gf_mgr[999]]: %NNT-TTEEEEMMGR3--TTTT_HHAAGGEEVENN ::    serrffficca no ddd   ..      hhhhoooootttttttttttttiiiivvvvv
# Generated log:  2022-10-01 01:00:01:  gf_mgr[999]]: %NNTTTTEEEEMMRR3--TT_T_HHANGGEEVENN :::    eeefffiinnn    ............/0ccaaaaaaaaaatttuuuuuuooiiivvveee
# Generated log:  2022-10-01 01:55:01:  gx_mgr[999]]: %NNTTTTTEEEMMRR3--TT_HHHHANGEEEVEN  ::    eeeefffiinnn     ...........000ccceeaaaaa ttttuuuuoouvvvveeee
# Generated log:  2022-10-01 02:20:01:  Ef_mgr[999]::%%NNTTTNEEEEMMR33--TT__HHAAGGEEVENT ::    eerffffaln           .   aaaa aoooooaattttttttttttiiiiivvvv
# Generated log:  2022-10-01 01:55:01:  gf_mgr[999]]: %NNTTTNEEEEMMR33--TT__HHHANGEEEVENT ::    eeerfffiilnn    ...........000ccaaaaaaaaaaaattttttooooovvvveee
# Generated log:  2022-10-01 01:25:01: bgf_mgr[999]]: %GBT-TTEEEEMMR33--TT_HHHHANGEEVVENT ::    eeeessiiiinn    .............0ccaaaaaaaaaaaatttuuuuuooooiiiieeecc
# Generated log:  2022-10-01 01:20:01:  gf_mgr[299]]: %METTTNNEEMMR----TT_HHHHAGGEEEEEN  ::    eerfffiiinno   ............00ccaaaaaaaaaattttttttuooooonnnii
# Time for epoch 3 is 2.614393949508667 sec
# Epoch: 3
# 1/1 [==============================] - 0s 20ms/step
# Generated log:  2022-10-01 02:00:01:  ff_mgr[920]]: %INT--SAATEMMGR-3-TTAT_CCANGEEEVENT : IIeeefffc    ddddd            nnnnttt-iiiiiiicc --
# Generated log:  2022-10-01 02:00:01:  ff_mgr[999]]: %INT--SAATEMMGR-3-TTTE_CHANGEEEVEN    I eeefffc    ddddd..           nnntttnnniiieeeee
# Generated log:  2222-10-01 02:00:01:  ff_mgr[928]]: %INT--SAATEMMGR-3-TTTT__CANGEEEVENT : IGeeefffc    dddd             nnntttniiiiiiicc  -
# Generated log:  2022-10-01 02:00:01:  ff_mgr[998]]: %INT--SAATEMMGR-3-TTAT_CCANGEEEVENT : I eeeeffc    ddddd..       aaee  tttt     ieeeeee--
# Generated log:  2022-10-01 02:00:01:  ff_mgr[999]]: %INT--SAATEMMGR-3-TTTT_CCANGEEEVENT : I eeefffc   cddddd           nnnntttn-iiiiiicce
# Generated log:  2222-10-01 02:00:01: iff_mgr[928]]: %INT--SAATEMMGR-3-TTAT__CHNGGEEVENT : IGeeeffac    dddd            nnnntttniiiiiiicc --                                                                                      6
# Generated log:  2022-10-01 02:00:01:  ff_mgr[998]]: %INT--SAATE_MGR-3-TTTT_CCANGEEEVENT :   eeeeffi      dd....    hhaaaeeetttttu    vveeeec---
# Generated log:  2022-10-01 02:00:01:  ff_mgr[929]]: %INT--SAATE_MGR-3-TTAT__CANGGEEVENT : IIeeefffc   cddddd          oonnnttt--iiiiiiicc  -
# Generated log:  2022-10-01 02:00:01:  ff_mgr[929]]: %INT--SAATEMMG--3-TTTE_CHANGEEEVENT     eeefffc    dddd...         e   ttt n    eeeeeee                                                                                FRR S:
# Generated log:  2022-10-01 02:00:01:  ff_mgr[929]]: %INT--SAATEMMGR-3-TTAT__CANGEEEVENT : IIeeefffc   addddd          onnnttt--iiiiiiiicc -                                                                                    Nv6
# Generated log:  2022-10-01 02:00:01:  ff_mgr[928]]: %INT--SAATE_MGR-3-TTAT__CHNGGEEVVNT :  Ieeefffc    ddddd           nnnntttn1iiiiiiicc  -
# Generated log:  2022-10-01 02:00:01: iff_mgr[999]]: %INT--SAATEMMGR-3-TTAT__CANGEEEVENT : IIeeeffac  caddddd t       oonnnttt-1iiiiiiicc --
# Generated log:  2022-10-01 02:00:01:  ff_mgr[999]]: %INT--SAATEMMGR-3-TTAT__CHNGGEEVVNT : IIeeefffcc ccdddddttt       oonnntttn-iiiiiiiice
# Generated log:  2022-10-01 02:00:01:  ff_mgr[928]]: %INT--SAATEMMGR-3-TTTT_CCANGEEEVENT   I eeefffc    ddddd.            nnnnnneeeeeeeeee --
# Generated log:  2022-10-01 02:00:01:  ff_mgr[999]]: %INT--SAATEMMGR-3-TTAT__CHNGGEEVVNT :  Geeeeffcc   ddddd .           nnnntttteeiiieeeee--
# Generated log:  2022-10-01 02:00:01:  ff_mgr[929]]: %INT--SAATE_MGR-3-TTTT_CCANGEEEVENT : I eeefffcc  cddddd            nnnnttt-iiiiiiicc
# Time for epoch 4 is 2.5925424098968506 sec
# Epoch: 4
# 1/1 [==============================] - 0s 21ms/step
# Generated log:  2222-10-01 02:00:01: iff_mgr[928]]: %INT--SAATEMMGR-3-TTTE_CHANGEEEVEN    I eeeffac   ddddd             nnnnttnniiiiiice                                                                                       %FF
# Generated log:  2222-10-01 02:00:01: iff_mgr[929]]: %INT--SAATEMMG--3-TTTE_CHANGEEEVEN    I eeeffac   ddddd .          nnnnntnniiiiiieee -                                                                                   %FFFR
# Generated log:  2222-10-01 02:00:01: iff_mgr[929]]: %INT--SAATEMMGR-3-TTTE_CHANGEEEVENT   I eeeffac   ddddd            nnnntttniiiiiiicc
# Generated log:  2022-10-01 02:00:01:  ff_mgr[999]]: %INT--SAATEMMGR-3-TTTT_CCANGEEEVENT : IGeeeffac    dddd             nnntttnniiiiiiccc -
# Generated log:  2222-10-01 02:00:01: iff_mgr[929]]: %INT--SAATEMMG--3-TTTE_CHANGEEEVEN    I eeeffac   ddddd             nnnnttnniiiiiicc --                                                                                 66
# Generated log:  2222-10-01 02:00:01: iff_mgr[929]]: %INT--SAATEMMG--3-TTTE_CHANGEEEVENT   I eeeffac   ddddd            nnnntttniiiiiiicc -                                                                                  666
# Generated log:  2022-10-01 02:00:01: iff_mgr[999]]: %INT--SAATEMMG--3-TTTE_CHANGEEEVEN    I eeeffac   ddddd            nnnntttniiiiiiicc                                                                              FFRRSSS ____
# Generated log:  2022-10-01 02:00:01:  ff_mgr[929]]: %INT--SAATEMMGR-3-TTTT_CCANGEEEVENT : IIeeeffac   ddddd            nnnntttn-iiiiiicc  -
# Generated log:  2222-10-01 02:00:01:  ff_mgr[928]]: %INT--SAATEMMGR-3-TTTE_CHANGEEEVENT   I eeeffac   ddddd             nnnnttniiiiiiicc --
# Generated log:  2222-10-01 02:00:01: iff_mgr[928]]: %INT--SAATEMMG--3-TTTE_CHANGEEEVEN    I eeeffac   ddddd .           nnnntnnniiiiieee --                                                                              RR6    EE
# Generated log:  2222-10-01 02:00:01: iff_mgr[928]]: %INT--SAATEMMGR-3-TTTE_CHANGEEEVEN    I eeeffac   ddddd .           nnnntnnniiiiieee -
# Generated log:  2022-10-01 02:00:01:  ff_mgr[988]]: %INT--SAATEMMG--3-TTTE_CHANGEEEVEN    I eeeffac   ddddd             nnnnnnnniiiiieeee--                                                                                      %
# Generated log:  2022-10-01 02:00:01: iff_mgr[999]]: %INT--SAATEMMG--3-TTTE_CHANGEEEVENT   I eeeffac   ddddd             nnntttnniiiiiicc  -                                                                              RRRRSS W_
# Generated log:  2022-10-01 02:00:01:  ff_mgr[998]]: %INT--SAATEMMG--3-TTTE_CHANGEEEVEN    I eeeffac   ddddd             nnnnntnnniiiieeee -                                                                                   6666
# Generated log:  2022-10-01 02:00:01: iff_mgr[999]]: %INT--SAATEMMG--3-TTTE_CHANGEEEVENT   I eeeffac  cddddd  t         nnnntttniiiiiiicc
# Generated log:  2222-10-01 02:00:01: iff_mgr[929]]: %INT--SAATEMMG--3-TTTE_CHANGEEEVEN    I eeeffac   ddddd            nnnntttniiiiiiicc -                                                                                  R66 S
# Time for epoch 5 is 2.5971150398254395 sec
# Epoch: 5
# 1/1 [==============================] - 0s 26ms/step
# Generated log:  2022-10-01 02:00:01: cif_mgr[100]]:%%GBT-SSATT__GG----TTTT__CHANGEEEVENT     Gseefffii     ............eaaaaaaaaaaaaatttttttooiiiiiiiiee
# Generated log:  2022-10-01 02:20:01: cif_mgr[115]]:%%BBT-SSTET_GGG----TT___CCAANGEEEVENT :    seeffiii     ............eeaaaaaaeeaaaaaaaaaatttoooiiiiiiii  eeee 1111               a
# Generated log:  2022-10-01 02:25:01: cgf_mgr2225]::%%BB--CCON_GGG-6--TT___CHnAEEEEEEENT :    eeeefiii     ..............aaaaaaeeetaaaaaattttttooooiiiiii   ee  1111              aaa
# Generated log:  2022-10-01 02:25:01: cif_mgr[115]]:%%BBT-SSTET_GGG----TT___CCAANGEEEVENN :    seeffiii    .............eaaaaaaaee aaaaataaattoooo   iiiii    e   11                a
# Generated log:  2022-10-01 02:55:01: cif_mgr[115]]:%%BBT-SSTTT_GGG----TT___CCAAGGEEEVNNT :  Gseeeffii     ............eaaaaaaaaaaaaatttttttiooiii iiiiee      ee                     a
# Generated log:  2022-10-01 02:25:01: cgx_mgr2211]::%%BB--CCTT__GGG6--TT___CCnnnEEEEEENT :    seeefiii     .............eaaaaaaaeaaaaaaaattttttttiiiiiiinnnee 11111       tt     aaa
# Generated log:  2022-10-01 02:25:01: cif_mgr[115]]:%%GB--SSTTT_GGG---TTTT__CHANGEEEVVNNT :   seeeffii     ............0aaaaaaeee  tttttttttooooo   niii      ee
# Generated log:  2022-10-01 02:25:01: cif_mgr[115]]:%%GBT-SSTET__GG----TT_T__CHANGEEEVENN ::   seeeffii     ............eaaaaaaaaaaaaaattaattooooiiiiiiiii    ee   11                a
# Generated log:  2022-10-01 02:55:01: cif_mgr[888]]:%%GBT-SSTTT_GGG----TTTT__CHANGEEEVENT :   seeeffii      ..........eeeaaaaaaaaaaatttttttooiiiiiiieeee
# Generated log:  2022-10-01 02:25:01: cif_mgr[115]]:%%BB--SSTET_GGG---TTT___CCAAGGEEVVNNT :    seeffiii    ..............aaaaaaeeeetttaaaaaattoooiiiiiiii     e   11                a
# Generated log:  2022-10-01 02:25:01: cgf_mgr[215]]:%%BB--SSTT__MGG-3-TT_T__CHAAGEEEVVNN ::   seeefiii     ............eaaaaaaaaeeeeaaaaaaattttttoooiiiii   eee111111              aa
# Generated log:  2022-10-01 02:55:01: cif_mgr[155]]:%%BBT-SSAET__GG----TT_T_CCHANGEEEVENT :   seeeffiii    ............eaaaaaaaaa attttttttoooiiiiiniieee
# Generated log:  2022-10-01 02:20:01: %of_mg[2215]::%%MB--CCON_MGG66-TT__CCCHnAEEEEEENN ::   seeeffii     ...............aaaaaaaeeattaattttttttiiiiiiiiinnnee 1111
# Generated log:  2022-10-01 02:25:01: cif_mgr[115]]:%%GB--SSTET_GGG---TTT___CHAAGEEEEVENT :   seeeffii     .............0aaaaaaee  taaaaaaattooooo   iiii     ee   1                aa
# Generated log:  2022-10-01 02:20:01: %gf_mgr2225]: %%GB--CON__GG-66-T__CCIIHAAEEEEEENT :   seeeefiii     ..............aaaaaaaaaaaattaattttttttoiiii innnnn 11111
# Generated log:  2022-10-01 02:25:01: cif_mgr[155]]:%%BBT-SSTET__GG----TTTT__CHANGEEEVVNN ::   seeeffii    .............aaaaaaaaee  tttttttttooooo    iiii                           a
# Time for epoch 6 is 2.5822131633758545 sec
# Epoch: 6
# 1/1 [==============================] - 0s 21ms/step
# Generated log:  2022-10-01 02:00:01: ii__mr[[905]: %%GFF-STATE_MG--3-STAT__CHANGEEEVENT : IIteeffaac ccndddd  ..     hhheeeeeeeeeetttteeiiiiiieee
# Generated log:  2022-10-01 01:00:01: ci_mmr[[885]: %%GT--STATE_MG--3-STTT_CCHANGEEEVNNT :  Iteefffac ccodddd   ...  hhhhhaaaaattttttunnniiiiiiivvvee
# Generated log:  2022-10-01 02:00:01: ci__mr[[885]: %%GT--STATE_MG--3-STTT_CCHAGGEEEVNNT :  Gseefffac cc dddd  ..... hhhhaaaaaatttttttunniiiiiiivvveee
# Generated log:  2022-10-01 02:25:01: ii__mr[[995]::%%NNT-SSATE_MGG-3-STTT__CHANGEEEVENT :  Ineefffaccccngddd ss...   hhhhhaeetttttttttteeeiiivvvvee
# Generated log:  2022-10-01 01:00:01: ii_mmr[[885]::%%GFF-STATE_MG--3-STTT_CCHANGEEEVENT :  Iteeffaaccccndddd  s..     hhheeaattttttttttteiiiiivvvc
# Generated log:  2022-10-01 02:00:01: ci__mr[[885]::%%BFF-STATE_MG--3-STTT_CCHANGEEEVENT :  Gseeeffaac co dddd ......hhhhhaaaaaatttttttooniiiiiiivvvvee
# Generated log:  2022-10-01 02:00:01: ci_mmr[8885]::%%NT--STATE_MG--3-STTT_CCHANGEEEVENT :  Iteeeffaccccodddd s......hhhhhaaaaattttttuunnniiiiiivvvvee
# Generated log:  2022-10-01 01:00:01: ci__mr[[885]::%%GFT-SSATE_MG--3-STTT_CCHANGEEEVENT :  Gteefffacc codddd  s..... hhhhaaaaattttttttnniiiiiivvveee
# Generated log:  2022-10-01 01:00:01: ci_mgr[8888]: %%GT--STATE_MG--3-TTTTCCCHANGEEVVNNT :  Gteeffaac ccodddd  ..... hhhhhaaaaatttttttnnniiiiiiivvvee
# Generated log:  2022-10-01 01:00:01: ii__mr[[885]::%%BFF-SSATE_MG--3-STTT_CCHAGGEEEVENT :  Gteeffaaccccndddd s....  hhhhhaaaattttttuunnteiiiiiiiiee
# Generated log:  2022-10-01 02:00:01: ci__mr[[885]::%%GFF-SSATE_MG--3-STTT_CCHANGEEEVENT :  Iteefffaccccodddd  s.....hhhhhaaaaatttttttunniiiiiiivvvee
# Generated log:  2022-10-01 01:00:01: ii__mr[[805]::%%NFF-SSATE_MG--3-STTT_CCHANGEEEVENT :  Ineefffaccccndddd  s...   hhhhhaaattttttttntteeiiiivvvvee
# Generated log:  2022-10-01 02:00:01: %i__mg[2255]::%%NNT-STATE_MGG---TTTTCCCHANGEEEVNNT :  Ineeeffaac coddddd s......ehhaaaaaaaaattttttnnniiiiiivvvvvee
# Generated log:  2022-10-01 02:05:01: ci__mgr[999]]:%%BNT-SSATT_MMG--3-STAT_CCHANGEEVVNNT :  Gteefffac  codddd   ..   hhhhhaaaeetttttttnnniiiiiiieee
# Generated log:  2022-10-01 01:00:01: ci__mr[[885]::%%GT--STATE_MG--3-STTT_CCHAGGEEEVENT :  Gteeeffaccccndddd ss.....hhhhhaaaaaatttttttnnniiiiiivvvvee
# Generated log:  2022-10-01 01:00:01: ci__mr[[885]: %%GT--STATE_MG----TTTT_CCHANGEEVVNNT :  Gteefffac  codddd   ...  hhhhhaaaaatttttttunniiiiiivvvee
# Time for epoch 7 is 2.6516427993774414 sec
# Epoch: 7
# 1/1 [==============================] - 0s 23ms/step
# Generated log:  2022-10-01 01:20:01: %ENNMON-22-N:OTUMLFT_OORRRG-DD  -----2  arnnggIIrrrree    fffmeee   bbuueeeeeeeeeIII42...  eeee      trpppeee  tt      t       gggg
# Generated log:  2022-10-01 01:20:01: %cNNMON-22-N:OTMMLFT__ORRRG-DD  -----2  arnngggIIrrrree   fffffattt  bbueeeeeeeeeeee442... eeeeee   tttpppprrtt  tttttttmm ccggggggg
# Generated log:  2022-10-01 01:15:01:  ENNMON222SN: UUMLFT__ORRRR:::    761     rngg                fffff       eexeee            eeeeee       tttee  ttttttttmm
# Generated log:  2022-10-01 01:20:01: %iNNMON-222N:OTMMLFT___GRRG-DD  r--9-2   rrngggIIrrrree     mmmit    eeuueeeeeeeeeee4s2..  eeeee      trrrrreeeeett      o    tttt
# Generated log:  2022-10-01 01:20:01: %iNNMON-222]:OT%MLTT___GRRG-DDD C--992   arnngggIIrraee     mmmaa    btuueeeeeeeeeess2... eeeeee     trrrrrreeeett            ttttt
# Generated log:  2022-10-01 01:10:01:  ENNMON2227]:  %MLFE___RRRR6P:    -77     rnngg              mm     bbb eeeeeee    442... eeeeeee    tttrrrrreeettttmm
# Generated log:  2022-10-01 01:25:01:  ENNMON-222N::TMMLTTT_ORRRG-DD   --9-1  arrnnggIrruraee   fffmmeett  be ueeeeeeeeeees42.... eeeee     trrreeeeeetttttt     ttttt  ggggg
# Generated log:  2022-10-01 01:10:01:  ENNMON[22SN:OUUMLFT__ORRRRMPP    761     rngg                             eee     e     .   eeee       ttppeeeeetttttm
# Generated log:  2022-10-01 01:20:01: %ENNMON-2--NSOOMMLFT__OGRRIMD:   -i---  arrngggIrrrrre     fffffeeffeeeeeeeeeee eeeee       ehhee       ttpppttttttttttttt        ggg
# Generated log:  2022-10-01 01:20:01: %ENNMON-22-N:OTMMLFT___MRRG-DD  r--9-2   rrnngg:Irrrree    aaaai    bbeueeeeeeeeeeII422...  eeee      tpppppe    tttttt  ccc gggg
# Generated log:  2022-10-01 01:10:01:  ENNMON222SN: TUMLFT___RRRRD:P    771     rngg                                         ..   eeeee      ppppr    tttttt mmccc
# Generated log:  2022-10-01 01:20:01: %ENNMON-22-NSOTMMLFT_OORRRG-DD  r--9-2  arrngggIIrrrree   fffffae    bbteeeeeeeeeeee442... eeeeeee     rrrpeeettttttt   tt     gggggg
# Generated log:  2022-10-01 01:20:01: %iNNMON-222N:OTMMLFT___GRRG-DD  C--992   rrngggIIrrrrree     mii     bueeeeeeeeeeeIII22.. eeeeeehh    ttrrrrrreetttt             tttt
# Generated log:  2022-10-01 01:20:01: %ENNMON-22-N:OT%TLTT___MRRG-DD  r--9-2   rrnngg:IIrrreee    ffmai    eeueeeeeeeeeeesss22.. eeeeeh      rrrrrreeetttttttttt       ttttt
# Generated log:  2022-10-01 01:10:01:  ENNMON222SN::TUMLFT___RRRRD::    761     rngg              f ffff                          eeeee       tpppetttttttttttt      gggg
# Generated log:  2022-10-01 01:20:01: %ENNMON-22-N:OTMMLTT___RRRG-DP  r----2  arnngggIIrrrree    ffffeee   eeeeeeeeeeeeeI4422... eeeeeh    tttppprreettttttttt   oo   ttttt
# Time for epoch 8 is 3.8082427978515625 sec
# Epoch: 8
# 1/1 [==============================] - 0s 22ms/step
# Generated log:  2022-10-01 02:20:01: ci__gr[1775]: %%G---STATE_GG----TTTT_CCHANGEEEVENT    Ineeefffii c   dd   .......ehhhhaaaaaaaaattttu niiiinnnvveeeeeEE 0
# Generated log:  2022-10-01 02:20:01: cof_gg[2255]: %%GB--STET__GGG---TT_T_CCHAGGGEEVENNT :  nseefffiii     d   ........eeahhaaaaaaaattttttooiniiinnnnneeeee0000
# Generated log:  2022-10-01 02:20:01: coffgg[2295]: %MGB--C-LTGGGG-3-TTT___CCHCEEEEEENNT     neeefffii          222.....eeehheeeeaaattttttttiiiiiiinnnnnnn   11       eee
# Generated log:  2022-10-01 02:20:01: cof_mg[2295]: %%GB--SSAT__GGG---TT_T_CCHAGGGEEVENNT :  nseefffiii  o     .........eeaaaaaaaaaaaattttttooiiiiiinnnnnneee444
# Generated log:  2022-10-01 02:20:01: cif_gg[1175]: %%GB--STATE_GG----TT_T_CCHAGGGEEVVNNT :  nseefffiii         ........ehhhhaaaaaaaatttttt iiiiiiinnnneeeee00000
# Generated log:  2022-10-01 02:20:01: cif_gr[1175]: %%G---STAT__GG----TTTT_CCHAGGGEEVENNT    nseefffii          ........ehhhhaaaaaaaattttttoiniiinnnnneeeeee00000
# Generated log:  2022-10-01 02:20:01: cif_gg[1295]: %%GB--SSAT__GG----TT_T_CCHANGGEEVENNT    nseefffii         .........ehhhaaaaaaaaaattttttoiiiiiinnnnneeeee 444
# Generated log:  2022-10-01 02:20:01:  of_gg[2299]: %%GB--SSAE__MGG---TT_T_CCHAGGGEEVVNNT :  Iseefffiii     d   .........eeahhaaaatttttttttttiiiiiiinnnnnnee
# Generated log:  2022-10-01 02:20:01: cENVgg[2273]: %MGB--CONNGGG-66-TT__ECCHCC  EEENNT     seeeffffii  oo     .........eeaaaeeeeattttttttttttiiiiiinnnnnn           eeee
# Generated log:  2022-10-01 02:20:01: cif_gg[1775]: %%G---SSAT__GG----TTTT_CCHAGGGEEVENNT    nseefffiiccc  dd   ........ehhhhaaaaaaaaatttt nniiiiiiivveeeee00000
# Generated log:  2022-10-01 02:20:01: cif_gr[1195]: %%G---SSATE_MG----STTT_CCHAGGEEEVENT  :  neeefffii         ........ hhhhhaaaaaaattttttoiiiiinnnnneeeeeee
# Generated log:  2022-10-01 02:20:01: cifmgr[1775]: %%G---STAT__GG----TTTT_CCHAGGGEEVENNT : Ineeefffaaccc dddd  s.......ehhhhaaaaaaaatttttunniiiiiinnveeeeeE0000
# Generated log:  2022-10-01 02:20:01: cif_gg[1195]: %%GB--SSAT__GG----TTTT_CCHAGGGEEVVNNT    Gseefffaacc    d   22......ehhhaaaaaaaaatttttt iniiiinnnneeeeee0000
# Generated log:  2022-10-01 02:20:01: cif_gr[1999]: %%G---SSATE_MG--3-TTTT_CCHAGGEEEVENNT   Ineeefffiic         .2......hhhhaaaaaaaaaaattttoiiiiiinnnn   eeee
# Generated log:  2022-10-01 02:20:01: cof_gg[2295]: %%GB--STET__GGG3--TT_T_CCHAGGGEEVENNT    nseefffiii         ........eeahhhaaaaaatttttttt iiiiiinnnnnneee441
# Generated log:  2022-10-01 02:20:01: cif_gr[1170]: %%G---STAT__GG----TTTT_CCHANGEEEVENNT    neeefffaa         ..22.... hhhaaaaaaaaatttttttoiniiiinnneeeeeeeE00
# Time for epoch 9 is 2.6239993572235107 sec
# Epoch: 9
# 1/1 [==============================] - 0s 21ms/step
# Generated log:  2022-10-01 02:20:01: ci_mgr[1205]: %IGT--STATE_MG--3-STAT_CCHANGEEEVENT      eeefffic         .......ehhhhaaaaaaatttttttoiiiiiiivvvvee
# Generated log:  2022-10-01 02:20:01: %gN_gg[2200]: %%G---SAEEE_MG--3-STAT_CCHANGEEEVVNNT :   seeeffii       ..........eaaaaaaeeeaaaaaaaaatttoooo  nniiii    ee
# Generated log:  2022-10-01 02:20:01: %gn_gg[2200]: %%G---STETE_MG--3-STAT_CCHANGEEEVVNNT :   seeeffii       .....000...eaaaaaaeeeaaaaaaatttttooooo  iiii   eee  14
# Generated log:  2022-10-01 02:20:01:  g__gg[2205]: %%G---STATE_MG--3-STAT_CCHANGEEEVVNNT     seeeffii       ..........aaaaaaaaaaaaaatttttttoiiiiiiiiiiii
# Generated log:  2022-10-01 02:20:01: cg__mr[1100]:%%%G---STATE_MG--3-STAT_CCHANGEEEVVNNT     seeeffii       .........eaaaaaaaeeaaaaaaaaatttoooii  vviii    ee
# Generated log:  2022-10-01 02:20:01: %gN_mg[2220]: %%GL--SAATE_MG--3-STAT_CCHANGEEEVVNNT :   seeeffii      ...........aaaaaaaeeaaaaaaattttttoooo  iiiiiieeee  11
# Generated log:  2022-10-01 02:20:01: %E__gg[2200]: %%G---STETE_MG--3-TTAT_CCHANGEEEVENNT     seefffii        .........eaaaaaaaaaaaaaaaattttoooo   iiii   eee
# Generated log:  2022-10-01 02:20:01: %o__gg[2205]: %%G---STATE_MG--3-STAT_CCHANGEEEVVNNT     seeeffii       ..........eaaaaaaaaaaaaaaaaattttoooo  iiiiii  ee
# Generated log:  2022-10-01 02:25:01:  g_mgg[2225]: %%N---STTT__MG--3-TTAT_CCHANGEEEVVNNT     seeeffii          .22....eeaaaaaaaaaaaaatttttttoooiiinniiie     e
# Generated log:  2022-10-01 02:20:01: ci__mg[2200]: %%G---STATE_MG--3-STAT_CCHANGEEEVENNT     seefffii        .........aaaaaaaaaaaaaatattttooiiiiiiiiiee
# Generated log:  2022-10-01 02:20:01: cgf_mr[1200]: %%GT--STATE_MG--3-STAT_CCHANGEEEVENTT     seefffii      ..........eaaaaaaaaaaaaattttttooiiiiiiiiiiee
# Generated log:  2022-10-01 02:20:01: ci_mgr[1100]: %%NF--STATE_MG--3-STAT_CCHANGEEEVENTT   I seefffii         .......ehhhhaaaaaaaattttttuoiiiiiivvvvvee
# Generated log:  2022-10-01 02:20:01: %gn_mg[2225]: %%GL--STETE_MG--3-STAT_CCHANGEEEVVNNT :   seeeffii       .....000..aaaaaaaeeaaaaaaaaattttoooo  iiiii  eee   41
# Generated log:  2022-10-01 02:25:01: bg__mr[1225]: %%GT--STATE_MGR-3-STATE_CHANGEEEVENTT     eeefffi         ........ehhhaaaaaaaatttttttoiiiiiiiivvve
# Generated log:  2022-10-01 02:20:01: %E__gg[2205]: %%N---SAET__MG--3-STAT_CCHANGEEEVVNNT     seefffiic        ........eeahaaaaaaaaaatttttttoooiiiiiiiinnnee
# Generated log:  2022-10-01 02:20:01: cif_mr[1100]: %%GF--STATE_MG--3-STAT__CHANGEEEVENTT     seefffii      ..........aaaaaaaaaaaaatttttttiiiiiiiiiiiiee
# Time for epoch 10 is 2.610135078430176 sec
# Epoch: 10
# 1/1 [==============================] - 0s 21ms/step
# Generated log:  2022-10-01 02:25:01: ii_mgr[1299]: %INT--STATE_MG--3-STATECCHANGEEEVENT    Iteerffaccccagddd  s  .     hhhhhaaatttttnnnnnn iiiivvvvc
# Generated log:  2022-10-01 02:25:01: ci_mgr[1219]: %INF--STATE_MG--3-STTTECCHANGEEEVENTT   Ineeeffaaccca dddd ss ..... hhhhhaaaaaatttttuuuuiiiiiiiivvveee
# Generated log:  2022-10-01 02:25:01:  i_mgr[2229]: %INT--STATE_MG--3-STTTECCHANGEEEVENTT   Ineeeffaacccangddd ss ..... hhhhhaaaaaattttttuunniiiiinivvveee
# Generated log:  2022-10-01 02:25:01: ci_mgr[1229]: %INT--STATE_MG--3-STATECCHANGEEEVENTT   Ineeeffaacccangdd  ss ..... hhhhhhaaaattttttuuuniiiiiiivvvvee
# Generated log:  2022-10-01 02:25:01: ci_mgr[1229]: %%NF--STATE_MG--3-STATECCHANGEEEVVNNT   Ineeefffic c        s .....hhhhhhaaaaaattttuuuuuuiiiiiiivvvee
# Generated log:  2022-10-01 02:25:01: ci_mgr[2228]: %INT--STATE_MG--3-STATECCHANGEEEVENTT   Ineeeffaacccagddd  ss ..... hhhhhaaaaatttttuuunniiiiiivvvveee
# Generated log:  2022-10-01 02:25:01:  i_mgr[2219]: %INT--STATE_MG--3-STATECCHANGEEEVENTT   Iteerffaacccangddd ss ...   hhhhhaaaaatttttuuunnnniinnvvvvee
# Generated log:  2022-10-01 02:25:01:  i_mgr[2229]: %%NT--STATE_MG--3-STTTECCHANGEEEVVNNT    neeeffaac ca dddd ss ..... hhhhhaaaaaattttttuuu iiiiiiivvveee
# Generated log:  2022-10-01 02:25:01:  i_mgr[2288]: %INF--STATE_MG--3-STTTECCHANGEEEVENTT   Ineerffaacccangddd ss ...   hhhhhaaaaatttttuunnnnniiinvvvveee
# Generated log:  2022-10-01 02:25:01: ci_mgr[1299]: %INT--STATE_MG--3-STATECCHANGEEEVENTT   Ineerffaccccangdd  ss.....  hhhhhaaaatttttuunnnniiiiiivvvvce
# Generated log:  2022-10-01 02:25:01: ii_mgr[9229]: %INT--STATE_MG--3-STATE_CHANGEEEVENT    Iteefffaccccngddd ss ..    hhhhhaaatttttuunn   iiiiiivvic
# Generated log:  2022-10-01 02:25:01: ci_mgr[1299]: %INT--STATE_MG--3-STATECCHANGE_EVENTT   Ineerffaccccaggdd  s ...   hhhhhhhaatttttnnnnnn iiiivvvvvc
# Generated log:  2022-10-01 02:25:01:  i_mgr[2228]: %INT--STATE_MG--3-STTTECCHANGEEEVENTT   Ineeeffaacccaggdd  ss...... hhhhhaaaaattttttuunniiiiiiivvveee E
# Generated log:  2022-10-01 02:25:01: ci_mgr[9229]: %%NT--STATE_MG--3-STATE_CHANGEEEVENTT   Iteeeffacc cagddd  s  ..   hhhhhhaaatttttuuunn iiiiiivvvve
# Generated log:  2022-10-01 02:25:01:  i_mgr[2229]: %INT--STTT__MG--3-STTTECCHANGEEEVENTT   Interffaacccangddd ss ..... hhhhhhaaaaatttttuuunniiiiinvvvvee
# Generated log:  2022-10-01 02:25:01: ci_mgr[1229]: %%NT--STATE_MG--3-STATECCHANGEEEVENTT   Iteeeffaac c  ddd  s  .... hhhhhhaaaatttttuuuuniiiiiiivvvcee
# Time for epoch 11 is 2.5883724689483643 sec
# Epoch: 11
# 1/1 [==============================] - 0s 20ms/step
# Generated log:  2022-10-01 02:00:01: iff_mgr[999]]: %INT--SAATEMMGR-3-TTAT__CHNNGEEVVNT :  Ieeefffcc  cddddd           nnnnttt-iiiiiiiicc  -
# Generated log:  2022-10-01 02:00:01:  ff_mgr[988]]: %INT--SAATEMMGR-3-TTAT__CHNNGEEVVNT :  Ieeefffcc   ddddd            nnnettt-iiiiiiicc  -                                                                                    SF
# Generated log:  2022-10-01 02:00:01:  ff_mgr[988]]: %INT--SAATEMMGR-3-TTAT__CHNNGEEVVNT :  Ieeefffcc   ddddd            nnnettt-iiiiiiicc  -                                                                                    FR
# Generated log:  2022-10-01 02:00:01:  ff_mgr[988]]: %INT--SAATE_MGR-3-TTAT__CHNNGEEVVNT :  Ieeeeffcc  cddddd  .         nnnntttniiiiiiiicc
# Generated log:  2022-10-01 02:00:01:  ff_mgr[988]]: %INT--SAATE_MGR-3-TTAT__CHNNGEEVVNT :  Ieeeeffcc  cddddd  .         nnnntttniiiiiiiicc                                                                                   FFFRR
# Generated log:  2022-10-01 02:00:01:  ff_mgr[988]]: %INT--SAATEMMGR-3-TTAT__CHNNGEEVVNT :  Ieeefffcc   ddddd            nnnettt-iiiiiiicc
# Generated log:  2022-10-01 02:00:01:  ff_mgr[988]]: %INT--SAATEMMGR-3-TTAT__CHNNGEEVVNT :  Ieeefffcc   ddddd            nnnetttniiiiiiicc                                                                                FFRRSSSW_
# Generated log:  2022-10-01 02:00:01:  ff_mgr[988]]: %INT--SAATEMMGR-3-TTAT__CHANGEEVVNT :  Ieeeeffcc  cddddd tt        onnntttn-iiiiiiiice
# Generated log:  2022-10-01 02:00:01:  ff_mgr[928]]: %INT--SAATEMMGR-3-TTAT__CHNNGEEVVNT :  Ieeeeffcc  cddddd            nnnettt-iiiiiiicc  -
# Generated log:  2022-10-01 02:00:01:  ff_mgr[988]]: %INT--SAATE_MGR-3-TTAT__CHNNGEEVVNT :  Ieeeeffcc  cddddd            nnnettt-iiiiiiiice
# Generated log:  2022-10-01 02:00:01:  ff_mgr[988]]: %INT--SAATEMMGR-3-TTAT__CHNNGEEVVNT :  Ieeeeffcc   ddddd            nnnettt-iiiiiiicce
# Generated log:  2022-10-01 02:00:01:  ff_mgr[988]]: %INT--SAATEMMGR-3-TTAT__CHNNGEEVVNT :  Ieeefffcc   ddddd            nnntttt-iiiiiiicc                                                                                    R66FS
# Generated log:  2022-10-01 02:00:01:  ff_mgr[988]]: %INT--SAATEMMGR-3-TTAT__CHNNGEEVVNT :  Ieeefffcc   ddddd            nnnetttniiiiiiicce                                                                              FFRR   : _
# Generated log:  2022-10-01 02:00:01:  ff_mgr[988]]: %INT--SAATEMMGR-3-TTAT__CHNNGEEVVNT :  Ieeefffcc   ddddd            nnnettt-iiiiiiicc                                                                                      SRR
# Generated log:  2022-10-01 02:00:01:  ff_mgr[988]]: %INT--SAATEMMGR-3-TTAT__CHNNGEEVVNT :  Ieeefffcc   ddddd            nnntttt-iiiiiiicc                                                                                   RRR-SS
# Generated log:  2022-10-01 02:00:01:  ff_mgr[988]]: %INT--SAATEMMGR-3-TTAT__CHNNGEEVVNT :  Ieeefffcc   ddddd            nnnettt-iiiiiiicc  -                                                                                   66F
# Time for epoch 12 is 2.6602437496185303 sec
# Epoch: 12
# 1/1 [==============================] - 0s 20ms/step
# Generated log:  2022-10-01 02:55:01:  ff_mgr[988]]: %INT--SAATE_MGR-3-TTATE_CHANGEEVVET :  I eeeffac  cndddd  .            nnntttttiiiiiiiccee--
# Generated log:  2022-10-01 02:55:01:  ff_mgr[988]]: %INT--SAATE_MGR-3-TTATE_CHANGEEVVEN    I eeeffic    dddd  ..      h     nnttttteiiiiiiieee--
# Generated log:  2022-10-01 02:55:01:  ff_mgr[988]]: %INT--SAATE_MGR-3-TTATE_CHANGEEVVEN    I eeefffc    dddd  ..      h e     nttttttiiiiieeeee-
# Generated log:  2022-10-01 02:25:01:  ff_mgr[988]]: %INT--SAATE_MGR-3-STATE_CHANGEEVVEN    I eeefffc  ccdddd  ..      hhe    nnntttttiiiiicceee--                                      s
# Generated log:  2022-10-01 02:55:01:  ff_mgr[988]]: %INT--SAATE_MGR-3-STATE_CHANGEEVVEN    I eeefffc  cadddd  ..           nnetttttiiiiiiiieee                                      s
# Generated log:  2022-10-01 02:55:01:  ff_mgr[988]]: %INT--SAATE_MGR-3-TTAT__CHANGEEVVEN    I eeefffc    dddd  ..           nnntttttiiiiiiieeee
# Generated log:  2022-10-01 02:00:01:  ff_mgr[988]]: %INT--SAATE_MGR-3-TTAT__CHANGEEVVET    I eeeffac  cadddd  .           nnnttttniiiiiiicce -
# Generated log:  2022-10-01 02:25:01:  ff_mgr[928]]: %INT--STATE_MGR-3-STATE_CHANGEEVVEN    I eeefffc  cadddd   .          ennettt--iiiiiiiieee
# Generated log:  2022-10-01 02:25:01:  ff_mgr[929]]: %INT--SAATE_MGR-3-TTATE_CHANGEEEVEN    I eeefffc  cadddd   .         ennnnettn-iiiiiivccee -
# Generated log:  2022-10-01 02:55:01:  ff_mgr[988]]: %INT--SAATE_MGR-3-TTAT__CHANGEEVVEN    I eeefffc    dddd  ..      h     nnntttttiiiiiiceee--                                      s
# Generated log:  2022-10-01 02:55:01:  ff_mgr[988]]: %INT--SAATE_MGR-3-STATE_CHANGEEVVEN    I eeefffc  cadddd  ..          nnnetttn-iiiiiiieee
# Generated log:  2022-10-01 02:05:01:  ff_mgr[988]]: %INT--SAATE_MGR-3-TTAT__CHANGEEVVET    I eeeffic    dddd ..            nnntttttiiiiiiicee--
# Generated log:  2022-10-01 02:55:01:  ff_mgr[988]]: %INT--SAATE_MGR-3-TTATE_CHANGEEVVEN    I eeeffic  c dddd ...      h    nnntttttiiiiiiieee--                                     ss
# ...
# Generated log:  2022-10-01 02:20:01: if_mgr[2222]: %INTF-STATE_MGR-3-STATE_CHANGE_EVENT : Interfaceecchanged state tto down::tt------   ndeevie  ----
# Generated log:  2022-10-01 02:20:01: if_mgr[2222]: %INTF-STATE_MGR-3-STATE_CHANGE_EVENT : Interfaceecchanged statee to down::tt------   nddeviee E---
# Generated log:  2022-10-01 02:20:01: if_mgr[2222]: %INTF-STATE_MGR-3-STATE_CHANGE_EVENT : Interfaceecchanged state too down: tt------    devvce  ---
# Generated log:  2022-10-01 02:20:01: if_mgr[2222]: %INTF-STATE_MGR-3-STATE_CHANGE_EVENT : Interfaceecchanged state too down: tt------    devvce  ---
# Generated log:  2022-10-01 02:20:01: if_mgr[2222]: %INTF-STATE_MGR-3-STATE_CHANGE_EVENT : Interfaceeccaanged state to doown: tt------  nddevice E---
# Generated log:  2022-10-01 02:20:01: if_mgr[2222]: %INTF-STATE_MGR-3-STATE_CHANGE_EVENT : Interfaceecchanged state to  down: tt------    devvce  ---
# Generated log:  2022-10-01 02:20:01: if_mgr[2222]: %INTF-STATE_MGR-3-STATE_CHANGE_EVENT : Interfaceecchanged ssatee to down::tt---1---  nddeviee  ---
# Generated log:  2022-10-01 02:20:01: if_mgr[2222]: %INTF-STATE_MGR-3-STATE_CHANGE_EVENT : Interfaceecchanged state  to down::tt------   nddeviee E---
# Generated log:  2022-10-01 02:20:01: if_mgr[2222]: %INTF-STATE_MGR-3-STATE_CHANGE_EVENT : Interfaceecchanged state to  oown: tt------   ddevice  ---
# Generated log:  2022-10-01 02:20:01: if_mgr[2222]: %INTF-STATE_MGR-3-STATE_CHANGE_EVENT : Interfaceecchanged state to  down: tt------    devvce  ---
# Generated log:  2022-10-01 02:20:01: if_mgr[2222]: %INTF-STATE_MGR-3-STATE_CHANGE_EVENT : Interfaceecchanged state too down::tt------    deevce  ----
# Generated log:  2022-10-01 02:20:01: if_mgr[2222]: %INTF-STATE_MGR-3-STATE_CHANGE_EVENT : Interfaceecchanged state to  oown: tt------   ddevice  ---
# Generated log:  2022-10-01 02:20:01: if_mgr[2222]: %INTF-STATE_MGR-3-STATE_CHANGE_EVENT : Interfaceeccaanged state to doown: tt------  nddevice E---
# Generated log:  2022-10-01 02:20:01: if_mgr[2222]: %INTF-STATE_MGR-3-STATE_CHANGE_EVENT : Interfaceecchanged ssatee to doww::ttt------  nddeviee  ---
# Generated log:  2022-10-01 02:20:01: if_mgr[2222]: %INTF-STATE_MGR-3-STATE_CHANGE_EVENT : Interfaceeccaanged state to doown: tt------  nddevice E---
# Time for epoch 37 is 2.600790023803711 sec
# Epoch: 37
# 1/1 [==============================] - 0s 21ms/step
# Generated log:  2022-10-01 02:20:01: if_mgr[2222]: %INTF-STATE_MGR-3-STATE_CHANGE_EVENT : Interface changee sstate to down: tt------    ddvviee ---
# Generated log:  2022-10-01 02:20:01: if_mgr[2222]: %INTF-STATE_MGR-3-STATE_CHANGE_EVENT : Interfaceeccangged state to down::tt------    ddvviee E---
# Generated log:  2022-10-01 02:20:01: if_mgr[2222]: %INTF-STATE_MGR-3-STATE_CHANGE_EVENT : Interfaceeccaanged state to doown: t---1--     deviee E---
# Generated log:  2022-10-01 02:20:01: if_mgr[2222]: %INTF-STATE_MGR-3-STATE_CHANGE_EVENT : Interfaceechangged state to down: tt------    ddvviee E---
# Generated log:  2022-10-01 02:20:01: if_mgr[2222]: %INTF-STATE_MGR-3-STATE_CHANGE_EVENT : Interfaceechangged state to down::tt------    ddvviee E---
# Generated log:  2022-10-01 02:20:01: if_mgr[2222]: %INTF-STATE_MGR-3-STATE_CHANGE_EVENT : Interface changed sstaee to down: tt------    devvce  ---
# Generated log:  2022-10-01 02:20:01: if_mgr[2222]: %INTF-STATE_MGR-3-STATE_CHANGE_EVENT : Interface changeed state to down: tt------    ddvviee ----
# Generated log:  2022-10-01 02:20:01: if_mgr[2222]: %INTF-STATE_MGR-3-STATE_CHANGE_EVENT : Interfaceeccaanged state to doown: t---1---    devvee  ---
# Generated log:  2022-10-01 02:20:01: if_mgr[2222]: %INTF-STATE_MGR-3-STATE_CHANGE_EVENT : Interfaceeccaanged state to doww:: t------     deviee E---
# Generated log:  2022-10-01 02:20:01: if_mgr[2222]: %INTF-STATE_MGR-3-STATE_CHANGE_EVENT : Interface changed sstaee to down: tt------    devvce  ---
# Generated log:  2022-10-01 02:20:01: if_mgr[2222]: %INTF-STATE_MGR-3-STATE_CHANGE_EVENT : Interface changee sstate to down: tt------    ddvviee ---
# Generated log:  2022-10-01 02:20:01: if_mgr[2222]: %INTF-STATE_MGR-3-STATE_CHANGE_EVENT : Interfaceeccaagged state to down::tt------    ddeviee E---
# Generated log:  2022-10-01 02:20:01: if_mgr[2222]: %INTF-STATE_MGR-3-STATE_CHANGE_EVENT : Interface changed sstaee to down: tt------    devvce  ---
# Generated log:  2022-10-01 02:20:01: if_mgr[2222]: %INTF-STATE_MGR-3-STATE_CHANGE_EVENT : Interface changed sstaee to down: tt-----     device E---
# Generated log:  2022-10-01 02:20:01: if_mgr[2222]: %INTF-STATE_MGR-3-STATE_CHANGE_EVENT : Interfaceeccaanged state to doown: t------     deviee E---
# Generated log:  2022-10-01 02:20:01: if_mgr[2222]: %INTF-STATE_MGR-3-STATE_CHANGE_EVENT : Interface changed sstaee to down: tt------    devvce  ---
# Time for epoch 38 is 2.6129274368286133 sec
# Epoch: 38
# 1/1 [==============================] - 0s 21ms/step
# Generated log:  2022-10-01 02:20:01: if_mgr[2222]: %INTF-STATE_MGR-3-STATE_CHANGE_EVENT : Interface changed state to down: tt------    device E---
# Generated log:  2022-10-01 02:20:01: if_mgr[2222]: %INTF-STATE_MGR-3-STATE_CHANGE_EVENT : Interface changed state to doow:: t------    ddvvic  ---
# Generated log:  2022-10-01 02:20:01: if_mgr[2222]: %INTF-STATE_MGR-3-STATE_CHANGE_EVENT : Interface changed state to ddown: t------     dvvice ----
# Generated log:  2022-10-01 02:20:01: if_mgr[2222]: %INTF-STATE_MGR-3-STATE_CHANGE_EVENT : Interface changed state to doow:: t------    ddvvic  ---
# Generated log:  2022-10-01 02:20:01: if_mgr[2222]: %INTF-STATE_MGR-3-STATE_CHANGE_EVENT : Interface changed state to down::tt------    devvie  ---
# Generated log:  2022-10-01 02:20:01: if_mgr[2222]: %INTF-STATE_MGR-3-STATE_CHANGE_EVENT : Interface changed state to down: tt-----     device ----
# Generated log:  2022-10-01 02:20:01: if_mgr[2222]: %INTF-STATE_MGR-3-STATE_CHANGE_EVENT : Interface changed state to down: tt------  n device  ---
# Generated log:  2022-10-01 02:20:01: if_mgr[2222]: %INTF-STATE_MGR-3-STATE_CHANGE_EVENT : Interface changed state to ddown: t----1-     dvvice ----
# Generated log:  2022-10-01 02:20:01: if_mgr[2222]: %INTF-STATE_MGR-3-STATE_CHANGE_EVENT : Interface changed state to ddown: t----1-     dvvice ----
# Generated log:  2022-10-01 02:20:01: if_mgr[2222]: %INTF-STATE_MGR-3-STATE_CHANGE_EVENT : Interface changed state to down: tt---1-     device E---
# Generated log:  2022-10-01 02:20:01: if_mgr[2222]: %INTF-STATE_MGR-3-STATE_CHANGE_EVENT : Interface changed state to down: tt------    device  ---
# Generated log:  2022-10-01 02:20:01: if_mgr[2222]: %INTF-STATE_MGR-3-STATE_CHANGE_EVENT : Interface changed state to doow:: t------    ddvvic  ---
# Generated log:  2022-10-01 02:20:01: if_mgr[2222]: %INTF-STATE_MGR-3-STATE_CHANGE_EVENT : Interface changed state to down::tt------    device  ---
# Generated log:  2022-10-01 02:20:01: if_mgr[2222]: %INTF-STATE_MGR-3-STATE_CHANGE_EVENT : Interface changed state to down: tt-----     device ----
# Generated log:  2022-10-01 02:20:01: if_mgr[2222]: %INTF-STATE_MGR-3-STATE_CHANGE_EVENT : Interface changed state ttoddown: t------     device ----
# Generated log:  2022-10-01 02:20:01: if_mgr[2222]: %INTF-STATE_MGR-3-STATE_CHANGE_EVENT : Interface changed state to down: tt---1-  i  device ----
# Time for epoch 39 is 2.6538710594177246 sec
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-42-07b49221e1c9> in <module>
# ----> 1 train(training_size, nb_epoch, batch_size)
#
# <ipython-input-41-944c8dd2522f> in train(training_size, epochs, batch)
#       6     while (batch_start+batch)<training_size:
#       7       (training_set,_) = load_batch(join(path_files,training_data_file),batch,batch_start)
# ----> 8       train_step(training_set)
#       9       batch_start += batch
#      10       batch_number +=1
#
# <ipython-input-34-325ebd9dc7ab> in train_step(real_logs)
#       3     #print('next_train_step')
#       4     with tf.GradientTape() as gen_tape, tf.GradientTape() as disc_tape:
# ----> 5       generated_logs = generator_model(noise, training=True)
#       6       real_output = discriminator_model(real_logs, training=True)
#       7       fake_output = discriminator_model(generated_logs, training=True)
#
# /usr/local/lib/python3.8/dist-packages/keras/utils/traceback_utils.py in error_handler(*args, **kwargs)
#      62     filtered_tb = None
#      63     try:
# ---> 64       return fn(*args, **kwargs)
#      65     except Exception as e:  # pylint: disable=broad-except
#      66       filtered_tb = _process_traceback_frames(e.__traceback__)
#
# /usr/local/lib/python3.8/dist-packages/keras/engine/training.py in __call__(self, *args, **kwargs)
#     488       layout_map_lib._map_subclass_model_variable(self, self._layout_map)
#     489
# --> 490     return super().__call__(*args, **kwargs)
#     491
#     492   @doc_controls.doc_in_current_and_subclasses
#
# /usr/local/lib/python3.8/dist-packages/keras/utils/traceback_utils.py in error_handler(*args, **kwargs)
#      62     filtered_tb = None
#      63     try:
# ---> 64       return fn(*args, **kwargs)
#      65     except Exception as e:  # pylint: disable=broad-except
#      66       filtered_tb = _process_traceback_frames(e.__traceback__)
#
# /usr/local/lib/python3.8/dist-packages/keras/engine/base_layer.py in __call__(self, *args, **kwargs)
#    1012         with autocast_variable.enable_auto_cast_variables(
#    1013             self._compute_dtype_object):
# -> 1014           outputs = call_fn(inputs, *args, **kwargs)
#    1015
#    1016         if self._activity_regularizer:
#
# /usr/local/lib/python3.8/dist-packages/keras/utils/traceback_utils.py in error_handler(*args, **kwargs)
#      90     bound_signature = None
#      91     try:
# ---> 92       return fn(*args, **kwargs)
#      93     except Exception as e:  # pylint: disable=broad-except
#      94       if hasattr(e, '_keras_call_info_injected'):
#
# /usr/local/lib/python3.8/dist-packages/keras/engine/sequential.py in call(self, inputs, training, mask)
#     372       if not self.built:
#     373         self._init_graph_network(self.inputs, self.outputs)
# --> 374       return super(Sequential, self).call(inputs, training=training, mask=mask)
#     375
#     376     outputs = inputs  # handle the corner case where self.layers is empty
#
# /usr/local/lib/python3.8/dist-packages/keras/engine/functional.py in call(self, inputs, training, mask)
#     456         a list of tensors if there are more than one outputs.
#     457     """
# --> 458     return self._run_internal_graph(
#     459         inputs, training=training, mask=mask)
#     460
#
# /usr/local/lib/python3.8/dist-packages/keras/engine/functional.py in _run_internal_graph(self, inputs, training, mask)
#     594
#     595         args, kwargs = node.map_arguments(tensor_dict)
# --> 596         outputs = node.layer(*args, **kwargs)
#     597
#     598         # Update tensor_dict.
#
# /usr/local/lib/python3.8/dist-packages/keras/utils/traceback_utils.py in error_handler(*args, **kwargs)
#      62     filtered_tb = None
#      63     try:
# ---> 64       return fn(*args, **kwargs)
#      65     except Exception as e:  # pylint: disable=broad-except
#      66       filtered_tb = _process_traceback_frames(e.__traceback__)
#
# /usr/local/lib/python3.8/dist-packages/keras/engine/base_layer.py in __call__(self, *args, **kwargs)
#     986         training=training_mode):
#     987
# --> 988       input_spec.assert_input_compatibility(self.input_spec, inputs, self.name)
#     989
#     990       if eager:
#
# /usr/local/lib/python3.8/dist-packages/keras/engine/input_spec.py in assert_input_compatibility(input_spec, inputs, layer_name)
#     194     # guarding for is a Layer instance (Functional API), which does not
#     195     # have a `shape` attribute.
# --> 196     if not hasattr(x, 'shape'):
#     197       raise TypeError(f'Inputs to a layer should be tensors. Got: {x}')
#     198
#
# /usr/local/lib/python3.8/dist-packages/tensorflow/python/framework/ops.py in shape(self)
#    1261         # `_tensor_shape` is declared and defined in the definition of
#    1262         # `EagerTensor`, in C.
# -> 1263         self._tensor_shape = tensor_shape.TensorShape(self._shape_tuple())
#    1264       except core._NotOkStatusException as e:
#    1265         raise core._status_to_exception(e) from None
#
# KeyboardInterrupt:

# %% [markdown]
# # Test GAN

# %%
generate_and_save_logs(generator_model,
                           nb_epoch,
                           seed)
# Out:
# 1/1 [==============================] - 0s 21ms/step
# Generated log:  2022-10-01 02:20:01: if_mgr[2222]: %INTF-STATE_MGR-3-STATE_CHANGE_EVENT : Interface changed state to down: tt------    device E---
# Generated log:  2022-10-01 02:20:01: if_mgr[2222]: %INTF-STATE_MGR-3-STATE_CHANGE_EVENT : Interface changed state to doow:: t------    ddvvic  ---
# Generated log:  2022-10-01 02:20:01: if_mgr[2222]: %INTF-STATE_MGR-3-STATE_CHANGE_EVENT : Interface changed state to doown: t------     dvvice ----
# Generated log:  2022-10-01 02:20:01: if_mgr[2222]: %INTF-STATE_MGR-3-STATE_CHANGE_EVENT : Interface changed state to doow:: t------    ddvvic  ---
# Generated log:  2022-10-01 02:20:01: if_mgr[2222]: %INTF-STATE_MGR-3-STATE_CHANGE_EVENT : Interface changed state to down::tt------    devvic  ---
# Generated log:  2022-10-01 02:20:01: if_mgr[2222]: %INTF-STATE_MGR-3-STATE_CHANGE_EVENT : Interface changed state to down: tt-----  i  device ----
# Generated log:  2022-10-01 02:20:01: if_mgr[2222]: %INTF-STATE_MGR-3-STATE_CHANGE_EVENT : Interface changed state to down: tt------  n device  ---
# Generated log:  2022-10-01 02:20:01: if_mgr[2222]: %INTF-STATE_MGR-3-STATE_CHANGE_EVENT : Interface changed state to ddown: t----1-     dvvice ----
# Generated log:  2022-10-01 02:20:01: if_mgr[2222]: %INTF-STATE_MGR-3-STATE_CHANGE_EVENT : Interface changed state to ddown: t------     dvvice ----
# Generated log:  2022-10-01 02:20:01: if_mgr[2222]: %INTF-STATE_MGR-3-STATE_CHANGE_EVENT : Interface changed state to down: tt------    device E---
# Generated log:  2022-10-01 02:20:01: if_mgr[2222]: %INTF-STATE_MGR-3-STATE_CHANGE_EVENT : Interface changed state to down::tt------    device  ---
# Generated log:  2022-10-01 02:20:01: if_mgr[2222]: %INTF-STATE_MGR-3-STATE_CHANGE_EVENT : Interface changed state to doow:: t------    ddvvic  ---
# Generated log:  2022-10-01 02:20:01: if_mgr[2222]: %INTF-STATE_MGR-3-STATE_CHANGE_EVENT : Interface changed state to down: tt------  n device  ---
# Generated log:  2022-10-01 02:20:01: if_mgr[2222]: %INTF-STATE_MGR-3-STATE_CHANGE_EVENT : Interface changed state to down: tt-----     device ----
# Generated log:  2022-10-01 02:20:01: if_mgr[2222]: %INTF-STATE_MGR-3-STATE_CHANGE_EVENT : Interface changed state ttoddown: t------     dvvice ----
# Generated log:  2022-10-01 02:20:01: if_mgr[2222]: %INTF-STATE_MGR-3-STATE_CHANGE_EVENT : Interface changed state to down: tt---1-  i  device ----

# %%
new_seed = tf.random.normal([num_examples_to_generate,noise_len, noise_dim])
generate_and_save_logs(generator_model,
                           nb_epoch,
                           new_seed)
# Out:
# 1/1 [==============================] - 0s 21ms/step
# Generated log:  2022-10-01 02:20:01: if_mgr[2222]: %INTF-STATE_MGR-3-STATE_CHANGE_EVENT : Interface changed state to down::tt------    devvie  ---
# Generated log:  2022-10-01 02:20:01: if_mgr[2222]: %INTF-STATE_MGR-3-STATE_CHANGE_EVENT : Interface changed state to down: tt-----  i  dvvic  ---
# Generated log:  2022-10-01 02:20:01: if_mgr[2222]: %INTF-STATE_MGR-3-STATE_CHANGE_EVENT : Interface changed state to down: tt------    device E---
# Generated log:  2022-10-01 02:20:01: if_mgr[2222]: %INTF-STATE_MGR-3-STATE_CHANGE_EVENT : Interface changed state to down: tt-----  i  dvvic  ---
# Generated log:  2022-10-01 02:20:01: if_mgr[2222]: %INTF-STATE_MGR-3-STATE_CHANGE_EVENT : Interface changed state to doow:: t------    ddvvic  ---
# Generated log:  2022-10-01 02:20:01: if_mgr[2222]: %INTF-STATE_MGR-3-STATE_CHANGE_EVENT : Interface changed state to ddown: t------     dvvice ----
# Generated log:  2022-10-01 02:20:01: if_mgr[2222]: %INTF-STATE_MGR-3-STATE_CHANGE_EVENT : Interface changed state  to down: t------     device E---
# Generated log:  2022-10-01 02:20:01: if_mgr[2222]: %INTF-STATE_MGR-3-STATE_CHANGE_EVENT : Interface changed state to doow:: t------     dvvice ---
# Generated log:  2022-10-01 02:20:01: if_mgr[2222]: %INTF-STATE_MGR-3-STATE_CHANGE_EVENT : Interface changed state to down: tt-----  i  dvvice ---
# Generated log:  2022-10-01 02:20:01: if_mgr[2222]: %INTF-STATE_MGR-3-STATE_CHANGE_EVENT : Interface changed state to down: tt------    device  ---
# Generated log:  2022-10-01 02:20:01: if_mgr[2222]: %INTF-STATE_MGR-3-STATE_CHANGE_EVENT : Interface changed state to down: tt---1--  n device E---
# Generated log:  2022-10-01 02:20:01: if_mgr[2222]: %INTF-STATE_MGR-3-STATE_CHANGE_EVENT : Interface changed state to doow:: t------    devvic  ---
# Generated log:  2022-10-01 02:20:01: if_mgr[2222]: %INTF-STATE_MGR-3-STATE_CHANGE_EVENT : Interface changed state to down: tt-----     device ----
# Generated log:  2022-10-01 02:20:01: if_mgr[2222]: %INTF-STATE_MGR-3-STATE_CHANGE_EVENT : Interface changed state to doow:: t------    ddvvic  ---
# Generated log:  2022-10-01 02:20:01: if_mgr[2222]: %INTF-STATE_MGR-3-STATE_CHANGE_EVENT : Interface changed state to down: tt-----  i  device ----
# Generated log:  2022-10-01 02:20:01: if_mgr[2222]: %INTF-STATE_MGR-3-STATE_CHANGE_EVENT : Interface changed state to ddown: t------     dvvice ----

# %%
generator_model.save_weights(join(path_files,'GAN_generator_dense_best.hdf5'))
discriminator_model.save_weights(join(path_files,'GAN_discriminator_dense_best.hdf5'))
